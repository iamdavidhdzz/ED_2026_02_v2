# %%
L = [-1, 3, 5, 7, 8, -23, -73]
L1 = [i ** 2 for i in L]
L1
# Out:
# [1, 9, 25, 49, 64, 529, 5329]

# %%
L.sort(key = lambda x:x**2)
L
# Out:
# [-1, 3, 5, 7, 8, -23, -73]

# %%
# Vamos con el ejemplo 1
entradas = [(5, "A"), (9,"C"), (3, "B"), (7,"D")]
entradas.sort(key = lambda x:x[1])
entradas
# Out:
# [(5, 'A'), (3, 'B'), (9, 'C'), (7, 'D')]

# %%
class cola_de_prioridad():
    def __init__(self):
        self.data = []

    def __len__(self):
        return len(self.data)

    def is_empty(self):
        return len(self) == 0

    def add(self, k, v):
        self.data.append((k,v))

    def _indice_min(self):
        i = 0
        for j in range(1, len(self)):
            if self.data[j][0] < self.data[i][0]:
                i = j
        return i

    def min(self):
        return self.data[self._indice_min()]

    def remove_min(self):
        i = self._indice_min()
        return self.data.pop(i)
