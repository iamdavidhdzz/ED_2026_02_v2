# %%
import pandas

# %%
from goodrich.ch08.linked_binary_tree import LinkedBinaryTree

# %%
L = LinkedBinaryTree()
root = L._add_root(10)
l = L._add_left(root,8)
r = L._add_right(root,20)

# %%
def find_min(T:LinkedBinaryTree):
    current = T.root()
    while T.left(current) is not None:
        current = T.left(current)
    return current

def find_max(T:LinkedBinaryTree):
    current = T.root()
    while T.right(current) is not None:
        current = T.right(current)
    return current

def is_ordered(T:LinkedBinaryTree): #Solucion más compleja
    I = T.inorder()
    a = next(I)
    for i in range (len(T)-2):
        b = next(I)
        if b.element() < a.element():
            return False
        a = next(I)
        a,b = b,a
    return True

def es_ordenado(T:LinkedBinaryTree):
    I = T.inorder()
    I1 = T.inorder()
    next(I1)
    for i in range(len(L)-1):
        if next(I).element() > next(I).element():
            return False
    return True
