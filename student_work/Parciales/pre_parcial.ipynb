# %%
Ejercicio 1. (2 puntos) Resolver los siguientes ejercicios:**
✓ Verdadero o falso: n5/2 es O(n2lnn).

✓ Hallar el valor de Nidiea([1,2,3,4]). Hallar la complejidad computacional de dicho algo

ritmo. Para esto tener en cuenta unicamente las asignaciones y operaciones aritm´eticas

def Niidea(S): n
   n = len(S)
   total = 0
    for j in range(0, n, 2):
        for i in range(0, 2):
            total = total + 2*S[j]*S[i]
    return total
# Out:
#   Cell In[2], line 2
#     ✓ Verdadero o falso: n5/2 es O(n2lnn).
#     ^
# SyntaxError: invalid character '✓' (U+2713)
